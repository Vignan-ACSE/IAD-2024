# %%
import os
import numpy as np
from keras.models import Model
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Dense, GlobalAveragePooling2D
from PIL import Image, ImageChops, ImageEnhance
import cv2
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpg'
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)
    ela_image = ImageChops.difference(image, temp_image)
    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1
    scale = 255.0 / max_diff
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)
    return ela_image

# %%
real_image_path = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/Au/Au_ani_00008.jpg'
Image.open(real_image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x256>

# %%
convert_to_ela_image(real_image_path, 95)
# Out:
# <PIL.Image.Image image mode=RGB size=384x256>

# %%
fake_image_path = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/Tp/Tp_D_CND_M_N_ani00018_sec00096_00138.tif'
Image.open(fake_image_path)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=384x256>

# %%
convert_to_ela_image(fake_image_path, 90)
# Out:
# <PIL.Image.Image image mode=RGB size=384x256>

# %%
image_size = (128, 128)

# %%
def prepare_image(image_path):
    return np.array(convert_to_ela_image(image_path, 90).resize(image_size)).flatten() / 255.0

# %%
X= []
y = []

# %%
import random
path = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/Au'
print(os.walk(path))
for root, dirs, files in os.walk(path):
    for filename in files:
        file_path = os.path.join(root, filename)
        if filename.lower().endswith(('jpg', 'png')):
            X.append(prepare_image(file_path))
            y.append(1)

random.shuffle(X)

print(len(X), len(y))
# Out:
# <generator object _walk at 0x786a5a8f4350>
# 7437 7437

# %%
import random
count = 0
path = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/Tp'
for root, dirs, files in os.walk(path):
    for filename in files:
        file_path = os.path.join(root, filename)
        if filename.lower().endswith(('jpg', 'png', 'tif', 'tiff')):
            X.append(prepare_image(file_path))
            y.append(0)

# %%
from keras.utils import to_categorical
X = np.array(X)
y = to_categorical(y, 2)
X = X.reshape(-1, 128, 128, 3)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X, y, test_size = 0.2, random_state=5)
X = X.reshape(-1,1,1,1)
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
# Out:
# 10048 10048
# 2512 2512

# %%
base_model= VGG16(weights='imagenet', include_top=False,input_shape=(128,128,3))

for layer in base_model.layers:
    layer.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(2, activation='softmax')(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model2 = Model(inputs=base_model.input, outputs=predictions)

# %%
from keras.optimizers import Adam
model2.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

from keras.callbacks import EarlyStopping,ModelCheckpoint
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5,mode='max', restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', save_best_only=True)
history = model2.fit(
    X_train, Y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, Y_val),
    callbacks=[early_stopping,model_checkpoint]
)
# Out:
# Epoch 1/50
# 314/314 [==============================] - 22s 57ms/step - loss: 0.4821 - accuracy: 0.7736 - val_loss: 0.3962 - val_accuracy: 0.8344
# Epoch 2/50
#   1/314 [..............................] - ETA: 11s - loss: 0.4934 - accuracy: 0.8125
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 314/314 [==============================] - 16s 50ms/step - loss: 0.4068 - accuracy: 0.8249 - val_loss: 0.4243 - val_accuracy: 0.8177
# Epoch 3/50
# 314/314 [==============================] - 16s 51ms/step - loss: 0.3941 - accuracy: 0.8316 - val_loss: 0.3808 - val_accuracy: 0.8372
# Epoch 4/50
# 314/314 [==============================] - 16s 52ms/step - loss: 0.3783 - accuracy: 0.8421 - val_loss: 0.3708 - val_accuracy: 0.8424
# Epoch 5/50
# 314/314 [==============================] - 16s 52ms/step - loss: 0.3705 - accuracy: 0.8458 - val_loss: 0.3620 - val_accuracy: 0.8515
# Epoch 6/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3681 - accuracy: 0.8442 - val_loss: 0.3538 - val_accuracy: 0.8559
# Epoch 7/50
# 314/314 [==============================] - 18s 56ms/step - loss: 0.3649 - accuracy: 0.8462 - val_loss: 0.3610 - val_accuracy: 0.8483
# Epoch 8/50
# 314/314 [==============================] - 17s 56ms/step - loss: 0.3590 - accuracy: 0.8484 - val_loss: 0.3685 - val_accuracy: 0.8408
# Epoch 9/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3549 - accuracy: 0.8502 - val_loss: 0.3684 - val_accuracy: 0.8443
# Epoch 10/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3504 - accuracy: 0.8551 - val_loss: 0.3435 - val_accuracy: 0.8583
# Epoch 11/50
# 314/314 [==============================] - 17s 55ms/step - loss: 0.3475 - accuracy: 0.8552 - val_loss: 0.3399 - val_accuracy: 0.8607
# Epoch 12/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3526 - accuracy: 0.8491 - val_loss: 0.3816 - val_accuracy: 0.8332
# Epoch 13/50
# 314/314 [==============================] - 17s 55ms/step - loss: 0.3425 - accuracy: 0.8551 - val_loss: 0.3392 - val_accuracy: 0.8619
# Epoch 14/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3445 - accuracy: 0.8560 - val_loss: 0.3356 - val_accuracy: 0.8619
# Epoch 15/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3406 - accuracy: 0.8545 - val_loss: 0.3581 - val_accuracy: 0.8535
# Epoch 16/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3360 - accuracy: 0.8586 - val_loss: 0.3330 - val_accuracy: 0.8583
# Epoch 17/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3310 - accuracy: 0.8583 - val_loss: 0.3370 - val_accuracy: 0.8615
# Epoch 18/50
# 314/314 [==============================] - 17s 55ms/step - loss: 0.3303 - accuracy: 0.8606 - val_loss: 0.3314 - val_accuracy: 0.8631
# Epoch 19/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3324 - accuracy: 0.8592 - val_loss: 0.3303 - val_accuracy: 0.8623
# Epoch 20/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3317 - accuracy: 0.8594 - val_loss: 0.3906 - val_accuracy: 0.8328
# Epoch 21/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3289 - accuracy: 0.8597 - val_loss: 0.3353 - val_accuracy: 0.8627
# Epoch 22/50
# 314/314 [==============================] - 17s 54ms/step - loss: 0.3275 - accuracy: 0.8636 - val_loss: 0.3297 - val_accuracy: 0.8599
# Epoch 23/50
# 314/314 [==============================] - 17s 55ms/step - loss: 0.3299 - accuracy: 0.8596 - val_loss: 0.3316 - val_accuracy: 0.8611

# %%
model2.evaluate(X_val,Y_val)
# Out:
# 79/79 [==============================] - 3s 42ms/step - loss: 0.3314 - accuracy: 0.8631
# [0.3313564956188202, 0.8630573153495789]

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
real_image_path1 = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/CASIA 2 Groundtruth/Tp_D_CNN_M_B_nat10139_nat00097_11948_gt.png'
Image.open(real_image_path1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
convert_to_ela_image(real_image_path1, 90)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
fake_image_path1 = '/kaggle/input/casia-20-image-tampering-detection-dataset/CASIA2/Au/Au_ani_00006.jpg'
Image.open(fake_image_path1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x256>

# %%
convert_to_ela_image(fake_image_path1, 95)
# Out:
# <PIL.Image.Image image mode=RGB size=384x256>

# %%
base_model= ResNet50(weights='imagenet', include_top=False,input_shape=(128,128,3))

for layer in base_model.layers:
    layer.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(2, activation='softmax')(x)

# %%
model3 = Model(inputs=base_model.input, outputs=predictions)

# %%
from keras.optimizers import Adam
model3.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

from keras.callbacks import EarlyStopping,ModelCheckpoint
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5,mode='max', restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', save_best_only=True)
history = model3.fit(
    X_train, Y_train,
    epochs=5,
    batch_size=32,
    validation_data=(X_val, Y_val),
    callbacks=[early_stopping,model_checkpoint]
)
# Out:
# Epoch 1/5
# 314/314 [==============================] - 22s 55ms/step - loss: 0.6735 - accuracy: 0.5856 - val_loss: 0.6355 - val_accuracy: 0.6158
# Epoch 2/5
# 314/314 [==============================] - 15s 47ms/step - loss: 0.6286 - accuracy: 0.6424 - val_loss: 0.6108 - val_accuracy: 0.7317
# Epoch 3/5
# 314/314 [==============================] - 14s 44ms/step - loss: 0.5668 - accuracy: 0.7062 - val_loss: 0.5370 - val_accuracy: 0.6672
# Epoch 4/5
# 314/314 [==============================] - 14s 45ms/step - loss: 0.5259 - accuracy: 0.7343 - val_loss: 0.5418 - val_accuracy: 0.7532
# Epoch 5/5
# 314/314 [==============================] - 14s 45ms/step - loss: 0.5253 - accuracy: 0.7365 - val_loss: 0.5152 - val_accuracy: 0.7695

# %%
model3.evaluate(X_val,Y_val)
# Out:
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5152 - accuracy: 0.7695
# [0.5152209401130676, 0.7695063948631287]
